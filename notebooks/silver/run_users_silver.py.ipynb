# %%
import os
import sys

repo_path = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.append(repo_path)

from src.silver.users import ingest_users_silver
from src.common.logger import get_logger

logger = get_logger(__name__)
spark.conf.set("spark.sql.session.timeZone", "Asia/Shanghai")

# =========================
# params
# =========================
dbutils.widgets.text("run_date", "")
run_date_param = dbutils.widgets.get("run_date")

if run_date_param:
    run_date_str = run_date_param
else:
    run_date_str = spark.sql(
        "select date_sub(current_date(),1)"
    ).first()[0].strftime("%Y-%m-%d")

logger.info(f"RUN_DATE = {run_date_str}")

# =========================
# run
# =========================
try:
    ingest_users_silver(spark, run_date_str)
except Exception as e:
    logger.error(f"Silver users failed: {e}", exc_info=True)
    raise
