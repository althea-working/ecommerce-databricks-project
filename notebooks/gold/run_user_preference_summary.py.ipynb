# %%
import sys
import os

repo_path = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.append(repo_path)

from src.gold.user_preference_summary import build_user_preference_summary
from src.common.logger import get_logger

logger = get_logger(__name__)

spark.conf.set("spark.sql.session.timeZone", "Asia/Shanghai")

logger.info("Run user preference summary start")

try:
    build_user_preference_summary(spark)
except Exception as e:
    logger.error(f"Run user preference summary failed: {e}", exc_info=True)
    raise
